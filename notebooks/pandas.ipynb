# %%
import pandas as pd

url_prefix = "https://raw.githubusercontent.com/coderefinery/data-visualization-python/main/data/"
data = pd.read_csv(url_prefix + "tromso-daily.csv")

# %%
# print an overview of the dataset
data
# Out:
#                  name  station        date  max temperature  min temperature  \
# 0    Tromsø - Langnes  SN90490  09.10.2022              6.9              4.7
# 1    Tromsø - Langnes  SN90490  10.10.2022              9.5              5.1
# 2    Tromsø - Langnes  SN90490  11.10.2022             10.7              4.5
# 3    Tromsø - Langnes  SN90490  12.10.2022              7.2              3.5
# 4    Tromsø - Langnes  SN90490  13.10.2022              8.2              4.2
# ..                ...      ...         ...              ...              ...
# 361  Tromsø - Langnes  SN90490  05.10.2023              3.9              1.4
# 362  Tromsø - Langnes  SN90490  06.10.2023              3.0              0.2
# 363  Tromsø - Langnes  SN90490  07.10.2023              2.5             -0.6
# 364  Tromsø - Langnes  SN90490  08.10.2023              4.0              0.8
# 365  Tromsø - Langnes  SN90490  09.10.2023              3.7              1.1
#
#      snow depth  precipitation
# 0             0           20.0
# 1             0            8.3
# 2             0            3.0
# 3             0            6.0
# 4             0           18.0
# ..          ...            ...
# 361           0            5.4
# 362           0           20.3
# 363           0           13.5
# 364           0            9.0
# 365           0            3.0
#
# [366 rows x 7 columns]

# %%
# print the first 5 rows
data.head()
# Out:
#                name  station        date  max temperature  min temperature  \
# 0  Tromsø - Langnes  SN90490  09.10.2022              6.9              4.7
# 1  Tromsø - Langnes  SN90490  10.10.2022              9.5              5.1
# 2  Tromsø - Langnes  SN90490  11.10.2022             10.7              4.5
# 3  Tromsø - Langnes  SN90490  12.10.2022              7.2              3.5
# 4  Tromsø - Langnes  SN90490  13.10.2022              8.2              4.2
#
#    snow depth  precipitation
# 0           0           20.0
# 1           0            8.3
# 2           0            3.0
# 3           0            6.0
# 4           0           18.0

# %%
# print the last 5 rows
data.tail()
# Out:
#                  name  station        date  max temperature  min temperature  \
# 361  Tromsø - Langnes  SN90490  05.10.2023              3.9              1.4
# 362  Tromsø - Langnes  SN90490  06.10.2023              3.0              0.2
# 363  Tromsø - Langnes  SN90490  07.10.2023              2.5             -0.6
# 364  Tromsø - Langnes  SN90490  08.10.2023              4.0              0.8
# 365  Tromsø - Langnes  SN90490  09.10.2023              3.7              1.1
#
#      snow depth  precipitation
# 361           0            5.4
# 362           0           20.3
# 363           0           13.5
# 364           0            9.0
# 365           0            3.0

# %%
# print all column titles - no parentheses here
data.columns
# Out:
# Index(['name', 'station', 'date', 'max temperature', 'min temperature',
#        'snow depth', 'precipitation'],
#       dtype='object')

# %%
# show which data types were detected
data.dtypes
# Out:
# name                object
# station             object
# date                object
# max temperature    float64
# min temperature    float64
# snow depth           int64
# precipitation      float64
# dtype: object

# %%
# print table dimensions - no parentheses here
data.shape
# Out:
# (366, 7)

# %%
# print one column
data["max temperature"]
# Out:
# 0       6.9
# 1       9.5
# 2      10.7
# 3       7.2
# 4       8.2
#        ...
# 361     3.9
# 362     3.0
# 363     2.5
# 364     4.0
# 365     3.7
# Name: max temperature, Length: 366, dtype: float64

# %%
# get some statistics
data["max temperature"].describe()
# Out:
# count    366.000000
# mean       6.400000
# std        7.228327
# min       -7.900000
# 25%        0.725000
# 50%        5.500000
# 75%       10.850000
# max       26.700000
# Name: max temperature, dtype: float64

# %%
# what was the maximum temperature?
data["max temperature"].max()
# Out:
# 26.7

# %%
# print all rows where max temperature was above 20
data[data["max temperature"] > 20.0]
# Out:
#                  name  station        date  max temperature  min temperature  \
# 254  Tromsø - Langnes  SN90490  20.06.2023             22.0             12.2
# 256  Tromsø - Langnes  SN90490  22.06.2023             25.4             12.6
# 264  Tromsø - Langnes  SN90490  30.06.2023             20.6             10.7
# 275  Tromsø - Langnes  SN90490  11.07.2023             22.8              9.3
# 276  Tromsø - Langnes  SN90490  12.07.2023             26.7             13.0
# 277  Tromsø - Langnes  SN90490  13.07.2023             25.8             14.2
# 278  Tromsø - Langnes  SN90490  14.07.2023             21.7             15.1
# 281  Tromsø - Langnes  SN90490  17.07.2023             21.8             13.4
# 290  Tromsø - Langnes  SN90490  26.07.2023             20.2             10.8
# 296  Tromsø - Langnes  SN90490  01.08.2023             20.6             11.7
# 297  Tromsø - Langnes  SN90490  02.08.2023             22.1             12.6
# 298  Tromsø - Langnes  SN90490  03.08.2023             23.5             16.3
# 299  Tromsø - Langnes  SN90490  04.08.2023             20.5             14.1
# 303  Tromsø - Langnes  SN90490  08.08.2023             24.9             11.0
# 304  Tromsø - Langnes  SN90490  09.08.2023             25.1             15.2
# 305  Tromsø - Langnes  SN90490  10.08.2023             21.0             13.5
# 306  Tromsø - Langnes  SN90490  11.08.2023             21.3             11.0
# 308  Tromsø - Langnes  SN90490  13.08.2023             20.7             11.4
#
#      snow depth  precipitation
# 254           0            0.0
# 256           0            0.0
# 264           0            0.0
# 275           0            0.0
# 276           0            0.0
# 277           0            0.0
# 278           0            0.0
# 281           0            2.5
# 290           0            0.0
# 296           0            0.0
# 297           0            0.0
# 298           0            0.0
# 299           0            0.0
# 303           0           12.0
# 304           0            0.0
# 305           0            0.0
# 306           0            2.6
# 308           0            0.2

# %%
# we don't need to import again but just in case you started here
import pandas as pd

url_prefix = "https://raw.githubusercontent.com/coderefinery/data-visualization-python/main/data/"

data_tromso = pd.read_csv(url_prefix + "tromso-monthly.csv")
data_oslo = pd.read_csv(url_prefix + "oslo-monthly.csv")

data = pd.concat([data_tromso, data_oslo], axis=0)

# let us print the combined result
data
# Out:
#                 name  station     date  max temperature  precipitation  \
# 0   Tromsø - Langnes  SN90490  10.2022             10.7          187.0
# 1   Tromsø - Langnes  SN90490  11.2022              8.5           41.5
# 2   Tromsø - Langnes  SN90490  12.2022              5.6           88.8
# 3   Tromsø - Langnes  SN90490   1.2023              7.7          111.4
# 4   Tromsø - Langnes  SN90490   2.2023              6.6          171.3
# 5   Tromsø - Langnes  SN90490   3.2023              4.5          157.0
# 6   Tromsø - Langnes  SN90490   4.2023              9.8           85.0
# 7   Tromsø - Langnes  SN90490   5.2023             17.7          101.2
# 8   Tromsø - Langnes  SN90490   6.2023             25.4           43.4
# 9   Tromsø - Langnes  SN90490   7.2023             26.7           14.0
# 10  Tromsø - Langnes  SN90490   8.2023             25.1           43.4
# 11  Tromsø - Langnes  SN90490   9.2023             19.3          163.7
# 12  Tromsø - Langnes  SN90490  10.2023              9.8           64.8
# 0    Oslo - Blindern  SN18700  10.2022             17.1           82.9
# 1    Oslo - Blindern  SN18700  11.2022             15.1           83.4
# 2    Oslo - Blindern  SN18700  12.2022              6.5           85.5
# 3    Oslo - Blindern  SN18700   1.2023              7.2          100.5
# 4    Oslo - Blindern  SN18700   2.2023             10.2           46.0
# 5    Oslo - Blindern  SN18700   3.2023              9.8           72.6
# 6    Oslo - Blindern  SN18700   4.2023             19.8           99.7
# 7    Oslo - Blindern  SN18700   5.2023             24.2           17.0
# 8    Oslo - Blindern  SN18700   6.2023             31.8           39.9
# 9    Oslo - Blindern  SN18700   7.2023             28.4          146.9
# 10   Oslo - Blindern  SN18700   8.2023             24.5          259.8
# 11   Oslo - Blindern  SN18700   9.2023             25.1          105.8
# 12   Oslo - Blindern  SN18700  10.2023             17.1            7.3
#
#     min temperature
# 0              -4.2
# 1              -7.0
# 2             -11.7
# 3             -13.9
# 4             -10.7
# 5             -15.1
# 6              -7.1
# 7              -4.6
# 8              -0.4
# 9               6.0
# 10              5.4
# 11              0.3
# 12             -0.6
# 0              -0.4
# 1              -2.1
# 2             -14.6
# 3             -13.4
# 4              -9.4
# 5             -12.6
# 6              -4.7
# 7              -0.8
# 8               4.6
# 9               8.6
# 10              9.8
# 11              5.3
# 12             -0.7

# %%
# replace mm.yyyy to date format
data["date"] = pd.to_datetime(list(data["date"]), format="%m.%Y")

# %%
import altair as alt

# %%
# this is here for google colab to update altair
if not alt.__version__.startswith("5"):
    # %pip install altair==5.1.2

# %%
alt.Chart(data).mark_bar().encode(
    x="date",
    y="precipitation",
    color="name",
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_bar().encode(
    x="date",
    y="precipitation",
    color="name",
    column="name",
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_bar().encode(
    x="name",
    y="precipitation",
    color="name",
    column="date",
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_area(opacity=0.5).encode(
    x="date",
    y="max temperature",
    y2="min temperature",
    color="name",
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_area(opacity=0.5).encode(
    x="date",
    y="max temperature",
    y2="min temperature",
    color="name",
    column="name",
)
# Out:
# alt.Chart(...)

# %%
url_prefix = "https://raw.githubusercontent.com/coderefinery/data-visualization-python/main/data/"

data_tromso = pd.read_csv(url_prefix + "tromso-daily.csv")
data_oslo = pd.read_csv(url_prefix + "oslo-daily.csv")

data = pd.concat([data_tromso, data_oslo], axis=0)

# %%
# replace dd.mm.yyyy to date format
data["date"] = pd.to_datetime(list(data["date"]), format="%d.%m.%Y")

# we are here only interested in the range december to may
data = data[(data["date"] > "2022-12-01") & (data["date"] < "2023-05-01")]

# %%
alt.Chart(data).mark_bar().encode(
    x="date",
    y="snow depth",
    column="name",
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_bar().encode(
    x="date",
    y="snow depth",
    color="max temperature",
    column="name",
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_bar().encode(
    x="date",
    y="snow depth",
    color=alt.Color("max temperature").scale(scheme="plasma"),
    column="name",
)
# Out:
# alt.Chart(...)

# %%
data = pd.read_csv("example.csv")

data
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
alt.Chart(data).mark_point().encode(
    x="x",
    y="y",
    color="dataset",
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_point().encode(
    x="x",
    y="y",
    color="dataset",
    column="dataset",
)
# Out:
# alt.Chart(...)
